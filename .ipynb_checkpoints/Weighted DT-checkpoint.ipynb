# %%
# Load libraries
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np

# %%
# load dataset
transactions = pd.read_csv("Data/creditcard.csv")
transactions.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
#split dataset in features and target variable
X = transactions.drop(['Class'], axis=1) # Features
y = transactions.Class # Target variable

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0) # 80% training and 20% test

# %%
# 'ccp_alpha': 0.001, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'auto'
# Create Decision Tree classifer object
clf = DecisionTreeClassifier(ccp_alpha= 0.001, criterion='gini', max_depth=5, max_features='auto')

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9988939995084443

# %%
#Creating the Confusion matrix    
cm= confusion_matrix(y_test, y_pred)

# %%
sns.heatmap(cm, annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(cm/np.sum(cm), annot=True, 
            fmt='.2%', cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print('\nAccuracy: {:.2f}\n'.format(accuracy_score(y_test, y_pred)))

print('Micro Precision: {:.2f}'.format(precision_score(y_test, y_pred, average='micro')))
print('Micro Recall: {:.2f}'.format(recall_score(y_test, y_pred, average='micro')))
print('Micro F1-score: {:.2f}\n'.format(f1_score(y_test, y_pred, average='micro')))

print('Macro Precision: {:.2f}'.format(precision_score(y_test, y_pred, average='macro')))
print('Macro Recall: {:.2f}'.format(recall_score(y_test, y_pred, average='macro')))
print('Macro F1-score: {:.2f}\n'.format(f1_score(y_test, y_pred, average='macro')))

print('Weighted Precision: {:.2f}'.format(precision_score(y_test, y_pred, average='weighted')))
print('Weighted Recall: {:.2f}'.format(recall_score(y_test, y_pred, average='weighted')))
print('Weighted F1-score: {:.2f}'.format(f1_score(y_test, y_pred, average='weighted')))

from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.00
#
# Micro Precision: 1.00
# Micro Recall: 1.00
# Micro F1-score: 1.00
#
# Macro Precision: 0.87
# Macro Recall: 0.79
# Macro F1-score: 0.83
#
# Weighted Precision: 1.00
# Weighted Recall: 1.00
# Weighted F1-score: 1.00
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56861
#            1       0.74      0.58      0.65       101
#
#     accuracy                           1.00     56962
#    macro avg       0.87      0.79      0.83     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
TP, FN, FP, TN = 0, 0, 0, 0

def confusion_matrix_for(cls, cm):
    TP = cm[cls, cls]
    FN = cm[cls].sum() - TP
    FP = cm[:, cls].sum() - TP
    TN = cm.sum() - TP - FN - FP
    return np.array([[TP, FN], [FP, TN]])

def getTotalAmountFalseNegative(df):
    df = df[df.case == 'false negative'] 
    totalAmount = 0
    for index, row in df.iterrows():
        totalAmount += row.Amount
    return totalAmount

def total_cost(cm, X_test, y_test, y_pred):
    for cls in range(cm.shape[0]):
        #print(f'[Class {cls} vs others]')
        TP, FN, FP, TN = confusion_matrix_for(cls, cm).ravel()
        #print(f'TP: {TP}, FN: {FN}, FP: {FP}, TN: {TN}')
    
    print(f'TP: {TP}, FN: {FN}, FP: {FP}, TN: {TN}')

    labels = np.array(['true negative',   # y_test, y_pred = 0,0
                   'false positive',  # y_test, y_pred = 0,1
                   'false negative',  # y_test, y_pred = 1,0
                   'true positive'    # y_test, y_pred = 1,1
                  ])

    X_test['case'] = labels[y_test * 2 + y_pred]
    Ca = 5
    TotalCost = getTotalAmountFalseNegative(X_test) + (FP + TP) * Ca
    print('Total cost: ' + str(TotalCost))

# %%
total_cost(cm, X_test, y_test, y_pred)
# Out:
# TP: 59, FN: 42, FP: 21, TN: 56840
# Total cost: 7967.540000000003

# %% [markdown]
# # Undersampling

# %%
# Split dataset into training set and test set
X_train_us, X_test_us, y_train_us, y_test_us = train_test_split(X, y, test_size=0.2, stratify=y) # 80% training and 20% test

# %%
from imblearn.under_sampling import RandomUnderSampler
rus = RandomUnderSampler(sampling_strategy=1) # Numerical value
# rus = RandomUnderSampler(sampling_strategy="not minority") # String
X_train_us, y_train_us = rus.fit_resample(X_train_us, y_train_us)

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf_us = clf.fit(X_train_us,y_train_us)

#Predict the response for test dataset
y_pred_us = clf_us.predict(X_test_us)

# %%
#Creating the Confusion matrix  
from sklearn.metrics import confusion_matrix  
cm_us = confusion_matrix(y_test_us, y_pred_us)

# %%
sns.heatmap(cm_us, annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(cm_us/np.sum(cm_us), annot=True, 
            fmt='.2%', cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
total_cost(cm_us, X_test_us, y_test_us, y_pred_us)
# Out:
# TP: 90, FN: 8, FP: 5320, TN: 51544
# Total cost: 29349.62

# %% [markdown]
# # Oversampling

# %%
from imblearn.over_sampling import SMOTE

# Split dataset into training set and test set
X_train_smt, X_test_smt, y_train_smt, y_test_smt = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42) # 80% training and 20% test

smote_technique = SMOTE(sampling_strategy='minority')
X_smt, y_smt = smote_technique.fit_resample(X_train_smt, y_train_smt)

# %%
# decisiontreeclassifier__ccp_alpha': 0.001, 'decisiontreeclassifier__criterion': 'gini', 'decisiontreeclassifier__max_depth': 5, 'decisiontreeclassifier__max_features': 'auto'
model_smt = DecisionTreeClassifier(max_features='auto', max_depth=5, criterion='gini', ccp_alpha=0.001)

# Train
model_smt = model_smt.fit(X_smt,y_smt)

#Predict the response for test dataset
y_pred_smt = model_smt.predict(X_test_smt)

# %%
#Creating the Confusion matrix  
from sklearn.metrics import confusion_matrix  
cm_smt = confusion_matrix(y_test_smt, y_pred_smt) 

sns.heatmap(cm_smt/np.sum(cm_smt), annot=True, 
            fmt='.2%', cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
total_cost(cm_smt, X_test_smt, y_test_smt, y_pred_smt)
# Out:
# TP: 89, FN: 9, FP: 1512, TN: 55352
# Total cost: 8667.4

# %% [markdown]
# # Grid Search

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

def get_x_elements_by_indices(x_train, indices):
    new_df = pd.DataFrame()
    for index in indices:
        try:
            new_df = new_df.append(x_train.iloc[index])
        except:
            print(str(index) + " not found")
    return new_df

def getTotalAmountFalseNegativeMyScorer(df, y_test, y_pred):
    fn_indices = []
    for ((index, row), i) in zip(y_test.items(), range(len(y_pred))):
        if y_pred[i]==0 and row!=y_pred[i]:
            fn_indices.append(index)
    print("No of FN: " + str(len(fn_indices)))
    df = df.iloc[fn_indices]
    totalAmount = 0
    for index, row in df.iterrows():
        totalAmount += row.Amount
    return totalAmount

def my_scorer(y_true, y_pred):
    model_cm = confusion_matrix(y_true, y_pred) 
    
    for cls in range(model_cm.shape[0]):
        #print(f'[Class {cls} vs others]')
        TP, FN, FP, TN = confusion_matrix_for(cls, model_cm).ravel() 
        
    labels = np.array(['true negative',   # y_test, y_pred = 0,0
                   'false positive',  # y_test, y_pred = 0,1
                   'false negative',  # y_test, y_pred = 1,0
                   'true positive'    # y_test, y_pred = 1,1
                  ])
    X_test_score = X
    # X_test_score = get_x_elements_by_indices(X_test_score, y_true.index)
    #print(labels[y_true * 2 + y_pred])
    #X_test_score['case'] = labels[y_true * 2 + y_pred]
    Ca = 5
    TotalCost = getTotalAmountFalseNegativeMyScorer(X_test_score, y_true, y_pred) + (FP + TP) * Ca
    print(TotalCost)
    return TotalCost

from sklearn.metrics import make_scorer
my_func = make_scorer(my_scorer, greater_is_better=False)

#my_scorer(y_test, y_pred)

# %%
fn_indices = []
for ((index, row), i) in zip(y_test.items(), range(len(y_pred))):
# for i in range(len(y_pred)): 
        if y_pred[i]==0 and row!=y_pred[i]:
            fn_indices.append(index)
            
fn_indices
# Out:
# [263080,
#  231978,
#  623,
#  55401,
#  57248,
#  105178,
#  275992,
#  239501,
#  243547,
#  68320,
#  149357,
#  4920,
#  102782,
#  100623,
#  157918,
#  191074,
#  197586,
#  142557,
#  220725,
#  248971]

# %%
param_grid = {'max_features': ['auto', 'sqrt', 'log2'],
              'ccp_alpha': [0.1, .01, .001],
              'max_depth' : [5, 6, 7, 8, 9],
              'criterion' :['gini', 'entropy']
             }

# %% [markdown]
# # Normal Dataset

# %%
from sklearn.model_selection import GridSearchCV

# Define parameters
max_depth = [5, 6, 7, 8, 9]
criterion = ['gini', 'entropy']
max_features = ['auto', 'sqrt', 'log2']
ccp_alpha = [0.1, .01, .001]
weights =  [{0:1.0, 1:10.0}, {0:1.0, 1:25.0}, {0:1.0, 1:50.0}]
param_grid = dict(max_depth=max_depth, criterion=criterion, max_features=max_features , ccp_alpha=ccp_alpha, class_weight=weights)

# Build the gridsearch
dtc = DecisionTreeClassifier(random_state=1024)
grid = GridSearchCV(estimator=dtc, param_grid=param_grid, scoring=my_func, cv = 5, verbose=10)

# %%
grid_results = grid.fit(X_train, y_train)

# Summarize the results in a readable format
print("Best: {0}, using {1}".format(grid_results.cv_results_['mean_test_score'], grid_results.best_params_))
results_df = pd.DataFrame(grid_results.cv_results_)
results_df
# Out:
# Fitting 5 folds for each of 270 candidates, totalling 1350 fits
# [CV 1/5; 1/270] START ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=5, max_features=auto
# No of FN: 78
# 7300.529999999998
# [CV 1/5; 1/270] END ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=5, max_features=auto;, score=-7300.530 total time=   0.7s
# [CV 2/5; 1/270] START ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=5, max_features=auto
# No of FN: 78
# 10858.949999999997
# [CV 2/5; 1/270] END ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=5, max_features=auto;, score=-10858.950 total time=   0.6s
# [CV 3/5; 1/270] START ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=5, max_features=auto
# No of FN: 78
# 6768.910000000001
# [CV 3/5; 1/270] END ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=5, max_features=auto;, score=-6768.910 total time=   0.6s
# [CV 4/5; 1/270] START ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=5, max_features=auto
# No of FN: 78
# 7686.04
# [CV 4/5; 1/270] END ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=5, max_features=auto;, score=-7686.040 total time=   0.6s
# [CV 5/5; 1/270] START ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=5, max_features=auto
# No of FN: 79
# 16510.07
# [CV 5/5; 1/270] END ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=5, max_features=auto;, score=-16510.070 total time=   0.6s
# [CV 1/5; 2/270] START ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=5, max_features=sqrt
# No of FN: 78
# 7300.529999999998
# [CV 1/5; 2/270] END ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=5, max_features=sqrt;, score=-7300.530 total time=   0.6s
# [CV 2/5; 2/270] START ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=5, max_features=sqrt
# No of FN: 78
# 10858.949999999997
# [CV 2/5; 2/270] END ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=5, max_features=sqrt;, score=-10858.950 total time=   0.7s
# [CV 3/5; 2/270] START ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=5, max_features=sqrt
# No of FN: 78
# 6768.910000000001
# [CV 3/5; 2/270] END ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=5, max_features=sqrt;, score=-6768.910 total time=   0.6s
# [CV 4/5; 2/270] START ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=5, max_features=sqrt
# No of FN: 78
# 7686.04
# [CV 4/5; 2/270] END ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=5, max_features=sqrt;, score=-7686.040 total time=   0.6s
# [CV 5/5; 2/270] START ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=5, max_features=sqrt
# No of FN: 79
# 16510.07
# [CV 5/5; 2/270] END ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=5, max_features=sqrt;, score=-16510.070 total time=   0.6s
# [CV 1/5; 3/270] START ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=5, max_features=log2
# No of FN: 78
# 7300.529999999998
# [CV 1/5; 3/270] END ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=5, max_features=log2;, score=-7300.530 total time=   0.5s
# [CV 2/5; 3/270] START ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=5, max_features=log2
# No of FN: 78
# 10858.949999999997
# [CV 2/5; 3/270] END ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=5, max_features=log2;, score=-10858.950 total time=   0.5s
# [CV 3/5; 3/270] START ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=5, max_features=log2
# No of FN: 78
# 6768.910000000001
# [CV 3/5; 3/270] END ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=5, max_features=log2;, score=-6768.910 total time=   0.5s
# [CV 4/5; 3/270] START ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=5, max_features=log2
# No of FN: 78
# 7686.04
# [CV 4/5; 3/270] END ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=5, max_features=log2;, score=-7686.040 total time=   0.5s
# [CV 5/5; 3/270] START ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=5, max_features=log2
# No of FN: 79
# 16510.07
# [CV 5/5; 3/270] END ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=5, max_features=log2;, score=-16510.070 total time=   0.5s
# [CV 1/5; 4/270] START ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=6, max_features=auto
# No of FN: 78
# 7300.529999999998
# [CV 1/5; 4/270] END ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=6, max_features=auto;, score=-7300.530 total time=   0.8s
# [CV 2/5; 4/270] START ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=6, max_features=auto
# No of FN: 78
# 10858.949999999997
# [CV 2/5; 4/270] END ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=6, max_features=auto;, score=-10858.950 total time=   0.8s
# [CV 3/5; 4/270] START ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=6, max_features=auto
# No of FN: 78
# 6768.910000000001
# [CV 3/5; 4/270] END ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=6, max_features=auto;, score=-6768.910 total time=   0.8s
# [CV 4/5; 4/270] START ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=6, max_features=auto
# No of FN: 78
# 7686.04
# [CV 4/5; 4/270] END ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=6, max_features=auto;, score=-7686.040 total time=   0.7s
# [CV 5/5; 4/270] START ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=6, max_features=auto
# No of FN: 79
# 16510.07
# [CV 5/5; 4/270] END ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=6, max_features=auto;, score=-16510.070 total time=   0.7s
# [CV 1/5; 5/270] START ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=6, max_features=sqrt
# No of FN: 78
# 7300.529999999998
# [CV 1/5; 5/270] END ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=6, max_features=sqrt;, score=-7300.530 total time=   0.8s
# [CV 2/5; 5/270] START ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=6, max_features=sqrt
# No of FN: 78
# 10858.949999999997
# [CV 2/5; 5/270] END ccp_alpha=0.1, class_weight={0: 1.0, 1: 10.0}, criterion=gini, max_depth=6, max_features=sqr
# 268           0.001  {0: 1.0, 1: 50.0}         entropy               9
# 269           0.001  {0: 1.0, 1: 50.0}         entropy               9
#
#     param_max_features                                             params  \
# 0                 auto  {'ccp_alpha': 0.1, 'class_weight': {0: 1.0, 1:...
# 1                 sqrt  {'ccp_alpha': 0.1, 'class_weight': {0: 1.0, 1:...
# 2                 log2  {'ccp_alpha': 0.1, 'class_weight': {0: 1.0, 1:...
# 3                 auto  {'ccp_alpha': 0.1, 'class_weight': {0: 1.0, 1:...
# 4                 sqrt  {'ccp_alpha': 0.1, 'class_weight': {0: 1.0, 1:...
# ..                 ...                                                ...
# 265               sqrt  {'ccp_alpha': 0.001, 'class_weight': {0: 1.0, ...
# 266               log2  {'ccp_alpha': 0.001, 'class_weight': {0: 1.0, ...
# 267               auto  {'ccp_alpha': 0.001, 'class_weight': {0: 1.0, ...
# 268               sqrt  {'ccp_alpha': 0.001, 'class_weight': {0: 1.0, ...
# 269               log2  {'ccp_alpha': 0.001, 'class_weight': {0: 1.0, ...
#
#      split0_test_score  split1_test_score  split2_test_score  \
# 0             -7300.53          -10858.95           -6768.91
# 1             -7300.53          -10858.95           -6768.91
# 2             -7300.53          -10858.95           -6768.91
# 3             -7300.53          -10858.95           -6768.91
# 4             -7300.53          -10858.95           -6768.91
# ..                 ...                ...                ...
# 265           -5098.08           -5116.72           -2874.38
# 266           -2868.19           -4570.53           -2290.34
# 267           -3609.03           -5042.73           -3204.76
# 268           -3609.03           -5042.73           -3204.76
# 269           -3404.58           -4390.48           -2811.71
#
#      split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0             -7686.04          -16510.07        -9824.900     3634.473778
# 1             -7686.04          -16510.07        -9824.900     3634.473778
# 2             -7686.04          -16510.07        -9824.900     3634.473778
# 3             -7686.04          -16510.07        -9824.900     3634.473778
# 4             -7686.04          -16510.07        -9824.900     3634.473778
# ..                 ...                ...              ...             ...
# 265           -3266.12           -3108.90        -3892.840      999.508516
# 266           -2788.12           -5052.56        -3513.948     1088.553042
# 267           -2976.12           -2654.83        -3497.494      832.802646
# 268           -2976.12           -2654.83        -3497.494      832.802646
# 269           -2821.12           -3698.35        -3425.248      591.284060
#
#      rank_test_score
# 0                226
# 1                226
# 2                226
# 3                226
# 4                226
# ..               ...
# 265              139
# 266               59
# 267               55
# 268               55
# 269               41
#
# [270 rows x 18 columns]

# %% [markdown]
# # SMOTE Dataset

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

def my_scorer_smt(y_true, y_pred):
    model_cm = confusion_matrix(y_true, y_pred) 
    
    for cls in range(model_cm.shape[0]):
        #print(f'[Class {cls} vs others]')
        TP, FN, FP, TN = confusion_matrix_for(cls, model_cm).ravel() 
        
    labels = np.array(['true negative',   # y_test, y_pred = 0,0
                   'false positive',  # y_test, y_pred = 0,1
                   'false negative',  # y_test, y_pred = 1,0
                   'true positive'    # y_test, y_pred = 1,1
                  ])
    X_test_score = X_smt
    # X_test_score = get_x_elements_by_indices(X_test_score, y_true.index)
    #print(labels[y_true * 2 + y_pred])
    #X_test_score['case'] = labels[y_true * 2 + y_pred]
    Ca = 5
    TotalCost = getTotalAmountFalseNegativeMyScorer(X_test_score, y_true, y_pred) + (FP + TP) * Ca
    print(TotalCost)
    return TotalCost

my_func_smt = make_scorer(my_scorer_smt, greater_is_better=False)

#my_scorer(y_test, y_pred)

# %%
from imblearn.pipeline import Pipeline, make_pipeline
# DecisionTreeClassifier
imba_pipeline = make_pipeline(SMOTE(random_state=42), 
                              DecisionTreeClassifier())

# %%
# grid_smt = GridSearchCV(estimator=dtc, param_grid=param_grid, scoring=my_func_smt, cv = 5, verbose=10)
new_params = {'decisiontreeclassifier__' + key: param_grid[key] for key in param_grid}
# grid_c = GridSearchCV(estimator=dfrst_c, param_grid=param_grid_criterion, scoring=my_func, cv = 5, verbose=10)return_train_score=True,
grid_imba = GridSearchCV(imba_pipeline, param_grid=new_params, cv=5, scoring=my_func_smt,  verbose=10)
grid_search_imba = grid_imba.fit(X_train, y_train);
# Out:
# Fitting 5 folds for each of 270 candidates, totalling 1350 fits
# [CV 1/5; 1/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 1/5; 1/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   1.9s
# [CV 2/5; 1/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 2/5; 1/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   2.0s
# [CV 3/5; 1/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 3/5; 1/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   1.8s
# [CV 4/5; 1/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 4/5; 1/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   1.9s
# [CV 5/5; 1/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 5/5; 1/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   1.7s
# [CV 1/5; 2/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 1/5; 2/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   1.7s
# [CV 2/5; 2/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 2/5; 2/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   1.7s
# [CV 3/5; 2/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 3/5; 2/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   1.7s
# [CV 4/5; 2/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 4/5; 2/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   1.8s
# [CV 5/5; 2/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 5/5; 2/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   1.8s
# [CV 1/5; 3/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 1/5; 3/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   1.2s
# [CV 2/5; 3/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 2/5; 3/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   1.2s
# [CV 3/5; 3/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 3/5; 3/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   1.2s
# [CV 4/5; 3/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 4/5; 3/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   1.2s
# [CV 5/5; 3/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 5/5; 3/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   1.3s
# [CV 1/5; 4/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 1/5; 4/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   1.6s
# [CV 2/5; 4/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 2/5; 4/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   1.6s
# [CV 3/5; 4/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 3/5; 4/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   1.7s
# [CV 4/5; 4/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 4/5; 4/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   1.5s
# [CV 5/5; 4/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 5/5; 4/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   1.6s
# [CV 1/5; 5/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 1/5; 5/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   1.7s
# [CV 2/5; 5/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 2/5; 5/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   1.8s
# [CV 3/5; 5/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 3/5; 5/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   2.0s
# [CV 4/5; 5/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 4/5; 5/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   2.0s
# [CV 5/5; 5/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 5/5; 5/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   2.0s
# [CV 1/5; 6/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 1/5; 6/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   1.7s
# [CV 2/5; 6/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 2/5; 6/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   1.8s
# [CV 3/5; 6/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 3/5; 6/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   1.8s
# [CV 4/5; 6/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 4/5; 6/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   1.8s
# [CV 5/5; 6/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 5/5; 6/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   1.8s
# [CV 1/5; 7/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 1/5; 7/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   2.1s
# [CV 2/5; 7/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 2/5; 7/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   2.2s
# [CV 3/5; 7/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 3/5; 7/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   2.2s
# [CV 4/5; 7/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 4/5; 7/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   2.3s
# [CV 5/5; 7/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 5/5; 7/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   2.3s
# [CV 1/5; 8/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 1/5; 8/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   2.3s
# [CV 2/5; 8/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 2/5; 8/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   2.2s
# [CV 3/5; 8/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 3/5; 8/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   2.4s
# [CV 4/5; 8/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 4/5; 8/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   2.1s
# [CV 5/5; 8/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 5/5; 8/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   2.2s
# [CV 1/5; 9/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 1/5; 9/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   1.9s
# [CV 2/5; 9/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 2/5; 9/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   1.9s
# [CV 3/5; 9/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 3/5; 9/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   1.9s
# [CV 4/5; 9/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 4/5; 9/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   1.9s
# [CV 5/5; 9/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 5/5; 9/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   1.9s
# [CV 1/5; 10/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 1/5; 10/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   2.4s
# [CV 2/5; 10/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 2/5; 10/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   2.3s
# [CV 3/5; 10/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 3/5; 10/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   2.4s
# [CV 4/5; 10/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 4/5; 10/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   2.4s
# [CV 5/5; 10/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 5/5; 10/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   2.4s
# [CV 1/5; 11/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 1/5; 11/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   2.6s
# [CV 2/5; 11/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 2/5; 11/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   2.6s
# [CV 3/5; 11/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 3/5; 11/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   2.6s
# [CV 4/5; 11/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 4/5; 11/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   2.5s
# [CV 5/5; 11/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 5/5; 11/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   2.3s
# [CV 1/5; 12/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 1/5; 12/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   2.0s
# [CV 2/5; 12/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 2/5; 12/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   2.1s
# [CV 3/5; 12/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 3/5; 12/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   2.1s
# [CV 4/5; 12/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 4/5; 12/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   2.1s
# [CV 5/5; 12/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 5/5; 12/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   2.2s
# [CV 1/5; 13/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 1/5; 13/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   2.6s
# [CV 2/5; 13/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 2/5; 13/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   2.8s
# [CV 3/5; 13/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 3/5; 13/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   2.4s
# [CV 4/5; 13/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 4/5; 13/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   2.5s
# [CV 5/5; 13/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 5/5; 13/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   2.4s
# [CV 1/5; 14/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 1/5; 14/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   2.3s
# [CV 2/5; 14/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 2/5; 14/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   1.9s
# [CV 3/5; 14/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 3/5; 14/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   1.9s
# [CV 4/5; 14/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 4/5; 14/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   1.9s
# [CV 5/5; 14/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 5/5; 14/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   2.0s
# [CV 1/5; 15/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 1/5; 15/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   1.7s
# [CV 2/5; 15/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 2/5; 15/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   1.7s
# [CV 3/5; 15/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 3/5; 15/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   1.8s
# [CV 4/5; 15/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 4/5; 15/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   2.3s
# [CV 5/5; 15/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 5/5; 15/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   2.1s
# [CV 1/5; 16/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=entropy, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 1/5; 16/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=entropy, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   2.4s
# [CV 2/5; 16/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=entropy, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 2/5; 16/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=entropy, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   2.4s
# [CV 3/5; 16/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=entropy, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=auto
# No of FN: 10
# 34843.08
# [CV 3/5; 16/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=entropy, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=auto;, score=-34843.080 total time=   2.4s
# [CV 4/5; 16/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=entropy, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 4/5; 16/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=entropy, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   2.5s
# [CV 5/5; 16/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=entropy, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 5/5; 16/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=entropy, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   2.4s
# [CV 1/5; 17/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=entropy, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 1/5; 17/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=entropy, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   2.4s
# [CV 2/5; 17/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=entropy, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=sqrt
# No of FN: 16
# 23849.59334259399
# [CV 2/5; 17/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=entropy, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=sqrt;, score=-23849.593 total time=   2.4s
# [CV 3/5; 17/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=entropy, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 3/5; 17/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=entropy, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   2.4s
# [CV 4/5; 17/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=entropy, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=sqrt
# No of FN: 8
# 13359.47
# [CV 4/5; 17/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=entropy, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=sqrt;, score=-13359.470 total time=   2.4s
# [CV 5/5; 17/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=entropy, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=sqrt
# No of FN: 7
# 17013.67
# [CV 5/5; 17/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=entropy, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=sqrt;, score=
}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [27], in <cell line: 3>()
#       1 # Summarize the results in a readable format
#       2 print("Best: {0}, using {1}".format(grid_search_imba.cv_results_['mean_test_score'], grid_search_imba.best_params_))
# ----> 3 results_df_smt = pd.DataFrame(grid_results_smt.cv_results_)
#       4 results_df_smt
#
# NameError: name 'grid_results_smt' is not defined

# %% [markdown]
# # Dropping outliers

# %%
from sklearn.ensemble import IsolationForest

anomaly_inputs = []
for name in transactions.columns[1:29]:
    anomaly_inputs.append(name)
anomaly_inputs.append('Class')

model_IF = IsolationForest(contamination=float(0.1),random_state=42)

anomaly_df = transactions
model_IF.fit(anomaly_df[anomaly_inputs])
# Out:
# C:\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# IsolationForest(contamination=0.1, random_state=42)

# %%
anomaly_df['anomaly_scores'] = model_IF.decision_function(anomaly_df[anomaly_inputs])
anomaly_df['anomaly'] = model_IF.predict(anomaly_df[anomaly_inputs])

# %%
df_wo_o = anomaly_df[(anomaly_df["anomaly"]==1) | ((anomaly_df["Class"]==1) & (anomaly_df["anomaly"]==-1))]
df_wo_o = df_wo_o.drop("anomaly", axis='columns')
df_wo_o = df_wo_o.drop("anomaly_scores", axis='columns')

# %%
from imblearn.over_sampling import SMOTE

#split dataset in features and target variable
X_wo_outliers = df_wo_o.drop(['Class'], axis=1) # Features
y_wo_outliers = df_wo_o.Class # Target variable

# Split dataset into training set and test set
X_train_smt_wo_outliers, X_test_smt_wo_outliers, y_train_smt_wo_outliers, y_test_smt_wo_outliers = train_test_split(X_wo_outliers, y_wo_outliers, test_size=0.2, stratify=y_wo_outliers, random_state=42) # 80% training and 20% test

smote_technique = SMOTE(sampling_strategy='minority')
X_smt_wo_outliers, y_smt_wo_outliers = smote_technique.fit_resample(X_train_smt_wo_outliers, y_train_smt_wo_outliers)

# %%
# decisiontreeclassifier__ccp_alpha': 0.001, 'decisiontreeclassifier__criterion': 'gini', 'decisiontreeclassifier__max_depth': 5, 'decisiontreeclassifier__max_features': 'auto'
model_smt_wo_outliers = DecisionTreeClassifier(max_features='auto', max_depth=5, criterion='gini', ccp_alpha=0.001)

# Train
model_smt_wo_outliers = model_smt_wo_outliers.fit(X_smt_wo_outliers,y_smt_wo_outliers)

#Predict the response for test dataset
y_pred_smt_wo_outliers = model_smt_wo_outliers.predict(X_test_smt_wo_outliers)

# %%
cm_smt_wo_outliers = confusion_matrix(y_test_smt_wo_outliers, y_pred_smt_wo_outliers) 

sns.heatmap(cm_smt_wo_outliers/np.sum(cm_smt_wo_outliers), annot=True, 
            fmt='.2%', cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
total_cost(cm_smt_wo_outliers, X_test_smt_wo_outliers, y_test_smt_wo_outliers, y_pred_smt_wo_outliers)
# Out:
# TP: 88, FN: 10, FP: 853, TN: 50404
# Total cost: 7584.08

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

def my_scorer_smt_wo_outliers(y_true, y_pred):
    model_cm = confusion_matrix(y_true, y_pred) 
    
    for cls in range(model_cm.shape[0]):
        #print(f'[Class {cls} vs others]')
        TP, FN, FP, TN = confusion_matrix_for(cls, model_cm).ravel() 
        
    labels = np.array(['true negative',   # y_test, y_pred = 0,0
                   'false positive',  # y_test, y_pred = 0,1
                   'false negative',  # y_test, y_pred = 1,0
                   'true positive'    # y_test, y_pred = 1,1
                  ])
    X_test_score = X_smt_wo_outliers
    # X_test_score = get_x_elements_by_indices(X_test_score, y_true.index)
    #print(labels[y_true * 2 + y_pred])
    #X_test_score['case'] = labels[y_true * 2 + y_pred]
    Ca = 5
    TotalCost = getTotalAmountFalseNegativeMyScorer(X_test_score, y_true, y_pred) + (FP + TP) * Ca
    print(TotalCost)
    return TotalCost

my_func_smt_wo_outliers = make_scorer(my_scorer_smt_wo_outliers, greater_is_better=False)

# %% [markdown]
# # Removing outliers + SMOTE

# %%
grid_imba_wo_outliers = GridSearchCV(imba_pipeline, param_grid=new_params, cv=5, scoring=my_func_smt_wo_outliers,  verbose=10)
grid_search_imba_wo_outliers = grid_imba_wo_outliers.fit(X_train, y_train);
# Out:
# Fitting 5 folds for each of 270 candidates, totalling 1350 fits
# [CV 1/5; 1/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 1/5; 1/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   1.9s
# [CV 2/5; 1/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 2/5; 1/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   1.8s
# [CV 3/5; 1/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 3/5; 1/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   1.9s
# [CV 4/5; 1/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 4/5; 1/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   1.8s
# [CV 5/5; 1/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 5/5; 1/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   1.8s
# [CV 1/5; 2/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 1/5; 2/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   1.9s
# [CV 2/5; 2/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 2/5; 2/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   2.0s
# [CV 3/5; 2/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 3/5; 2/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   2.0s
# [CV 4/5; 2/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 4/5; 2/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   1.8s
# [CV 5/5; 2/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 5/5; 2/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   1.9s
# [CV 1/5; 3/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 1/5; 3/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   1.7s
# [CV 2/5; 3/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 2/5; 3/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   1.7s
# [CV 3/5; 3/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 3/5; 3/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   1.7s
# [CV 4/5; 3/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 4/5; 3/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   1.7s
# [CV 5/5; 3/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 5/5; 3/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   1.6s
# [CV 1/5; 4/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 1/5; 4/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   2.1s
# [CV 2/5; 4/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 2/5; 4/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   2.2s
# [CV 3/5; 4/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 3/5; 4/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   2.3s
# [CV 4/5; 4/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 4/5; 4/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   1.9s
# [CV 5/5; 4/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 5/5; 4/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   2.0s
# [CV 1/5; 5/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 1/5; 5/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   2.3s
# [CV 2/5; 5/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 2/5; 5/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   2.2s
# [CV 3/5; 5/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 3/5; 5/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   2.1s
# [CV 4/5; 5/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 4/5; 5/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   2.2s
# [CV 5/5; 5/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 5/5; 5/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   2.2s
# [CV 1/5; 6/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 1/5; 6/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   1.9s
# [CV 2/5; 6/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 2/5; 6/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   1.9s
# [CV 3/5; 6/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 3/5; 6/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   1.9s
# [CV 4/5; 6/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 4/5; 6/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   1.7s
# [CV 5/5; 6/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 5/5; 6/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=6, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   1.6s
# [CV 1/5; 7/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 1/5; 7/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   2.2s
# [CV 2/5; 7/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 2/5; 7/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   2.2s
# [CV 3/5; 7/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 3/5; 7/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   1.6s
# [CV 4/5; 7/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 4/5; 7/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   1.6s
# [CV 5/5; 7/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 5/5; 7/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   1.7s
# [CV 1/5; 8/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 1/5; 8/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   1.7s
# [CV 2/5; 8/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 2/5; 8/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   1.7s
# [CV 3/5; 8/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 3/5; 8/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   1.8s
# [CV 4/5; 8/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 4/5; 8/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   1.8s
# [CV 5/5; 8/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 5/5; 8/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   1.8s
# [CV 1/5; 9/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 1/5; 9/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   2.0s
# [CV 2/5; 9/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 2/5; 9/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   2.0s
# [CV 3/5; 9/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 3/5; 9/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   2.0s
# [CV 4/5; 9/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 4/5; 9/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   2.0s
# [CV 5/5; 9/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 5/5; 9/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=7, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   2.1s
# [CV 1/5; 10/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 1/5; 10/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   2.8s
# [CV 2/5; 10/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 2/5; 10/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   2.8s
# [CV 3/5; 10/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 3/5; 10/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   2.7s
# [CV 4/5; 10/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 4/5; 10/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   2.6s
# [CV 5/5; 10/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 5/5; 10/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   2.8s
# [CV 1/5; 11/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 1/5; 11/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   2.7s
# [CV 2/5; 11/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 2/5; 11/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   2.7s
# [CV 3/5; 11/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 3/5; 11/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   2.8s
# [CV 4/5; 11/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 4/5; 11/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   2.7s
# [CV 5/5; 11/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 5/5; 11/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   2.8s
# [CV 1/5; 12/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 1/5; 12/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   2.6s
# [CV 2/5; 12/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 2/5; 12/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   2.7s
# [CV 3/5; 12/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 3/5; 12/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   2.7s
# [CV 4/5; 12/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 4/5; 12/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   2.7s
# [CV 5/5; 12/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 5/5; 12/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=8, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   2.5s
# [CV 1/5; 13/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 1/5; 13/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   3.0s
# [CV 2/5; 13/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 2/5; 13/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   2.8s
# [CV 3/5; 13/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 3/5; 13/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   3.1s
# [CV 4/5; 13/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 4/5; 13/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   3.5s
# [CV 5/5; 13/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=auto
# No of FN: 0
# 227845
# [CV 5/5; 13/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=auto;, score=-227845.000 total time=   3.4s
# [CV 1/5; 14/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 1/5; 14/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   3.6s
# [CV 2/5; 14/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 2/5; 14/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   3.5s
# [CV 3/5; 14/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 3/5; 14/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   3.4s
# [CV 4/5; 14/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 4/5; 14/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   3.0s
# [CV 5/5; 14/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=sqrt
# No of FN: 0
# 227845
# [CV 5/5; 14/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=sqrt;, score=-227845.000 total time=   3.4s
# [CV 1/5; 15/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 1/5; 15/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   2.9s
# [CV 2/5; 15/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 2/5; 15/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   3.1s
# [CV 3/5; 15/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 3/5; 15/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   3.0s
# [CV 4/5; 15/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 4/5; 15/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   3.0s
# [CV 5/5; 15/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=log2
# No of FN: 0
# 227845
# [CV 5/5; 15/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=gini, decisiontreeclassifier__max_depth=9, decisiontreeclassifier__max_features=log2;, score=-227845.000 total time=   3.0s
# [CV 1/5; 16/270] START decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=entropy, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=auto
# No of FN: 7
# 51854.733105865766
# [CV 1/5; 16/270] END decisiontreeclassifier__ccp_alpha=0.1, decisiontreeclassifier__class_weight={0: 1.0, 1: 10.0}, decisiontreeclassifier__criterion=entropy, decisiontreeclassifier__max_depth=5, decisiontreeclassifier__max_features=auto;, score=
# 265                          {0: 1.0, 1: 50.0}
# 266                          {0: 1.0, 1: 50.0}
# 267                          {0: 1.0, 1: 50.0}
# 268                          {0: 1.0, 1: 50.0}
# 269                          {0: 1.0, 1: 50.0}
#
#     param_decisiontreeclassifier__criterion  \
# 0                                      gini
# 1                                      gini
# 2                                      gini
# 3                                      gini
# 4                                      gini
# ..                                      ...
# 265                                 entropy
# 266                                 entropy
# 267                                 entropy
# 268                                 entropy
# 269                                 entropy
#
#     param_decisiontreeclassifier__max_depth  \
# 0                                         5
# 1                                         5
# 2                                         5
# 3                                         6
# 4                                         6
# ..                                      ...
# 265                                       8
# 266                                       8
# 267                                       9
# 268                                       9
# 269                                       9
#
#     param_decisiontreeclassifier__max_features  \
# 0                                         auto
# 1                                         sqrt
# 2                                         log2
# 3                                         auto
# 4                                         sqrt
# ..                                         ...
# 265                                       sqrt
# 266                                       log2
# 267                                       auto
# 268                                       sqrt
# 269                                       log2
#
#                                                 params  split0_test_score  \
# 0    {'decisiontreeclassifier__ccp_alpha': 0.1, 'de...     -227845.000000
# 1    {'decisiontreeclassifier__ccp_alpha': 0.1, 'de...     -227845.000000
# 2    {'decisiontreeclassifier__ccp_alpha': 0.1, 'de...     -227845.000000
# 3    {'decisiontreeclassifier__ccp_alpha': 0.1, 'de...     -227845.000000
# 4    {'decisiontreeclassifier__ccp_alpha': 0.1, 'de...     -227845.000000
# ..                                                 ...                ...
# 265  {'decisiontreeclassifier__ccp_alpha': 0.001, '...      -69339.983020
# 266  {'decisiontreeclassifier__ccp_alpha': 0.001, '...      -77002.375707
# 267  {'decisiontreeclassifier__ccp_alpha': 0.001, '...      -62698.461636
# 268  {'decisiontreeclassifier__ccp_alpha': 0.001, '...      -59402.401636
# 269  {'decisiontreeclassifier__ccp_alpha': 0.001, '...      -76921.771636
#
#      split1_test_score  split2_test_score  split3_test_score  \
# 0        -227845.00000     -227845.000000     -227845.000000
# 1        -227845.00000     -227845.000000     -227845.000000
# 2        -227845.00000     -227845.000000     -227845.000000
# 3        -227845.00000     -227845.000000     -227845.000000
# 4        -227845.00000     -227845.000000     -227845.000000
# ..                 ...                ...                ...
# 265       -76315.35000      -74319.715296      -67436.867226
# 266       -82269.93714      -72977.175296      -69858.770000
# 267       -56785.00000      -83403.585296      -81879.207226
# 268       -67414.00000      -61039.975296      -94844.607226
# 269       -78199.00000      -55744.885296      -73249.177226
#
#      split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -227845.00   -227845.000000        0.000000              179
# 1           -227845.00   -227845.000000        0.000000              179
# 2           -227845.00   -227845.000000        0.000000              179
# 3           -227845.00   -227845.000000        0.000000              179
# 4           -227845.00   -227845.000000        0.000000              179
# ..                 ...              ...             ...              ...
# 265         -109834.98    -79449.379108    15530.104068               85
# 266          -78890.00    -76199.651629     4366.276217               78
# 267          -71336.21    -71220.492832    10421.686946               74
# 268         -104584.99    -77457.194832    18625.819700               80
# 269         -105940.10    -78010.986832    16122.724394               82
#
# [270 rows x 18 columns]

# %%
from imblearn.under_sampling import RandomUnderSampler
imba_pipeline_us = make_pipeline(RandomUnderSampler(sampling_strategy=1), 
                              DecisionTreeClassifier())

# %%
grid_imba_us = GridSearchCV(imba_pipeline_us, param_grid=new_params, cv=5, scoring=my_func_smt,  verbose=10)
grid_search_imba = grid_imba.fit(X_train, y_train);
